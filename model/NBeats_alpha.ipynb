# %%
# ! pip install missingno
# ! pip install darts
# ! pip install utils
# Out:
# Requirement already satisfied: darts in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (0.23.1)
# Requirement already satisfied: tqdm>=4.60.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (4.62.2)
# Requirement already satisfied: statsforecast>=1.0.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (1.4.0)
# Requirement already satisfied: scipy>=1.3.2 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (1.10.0)
# Requirement already satisfied: pmdarima>=1.8.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (2.0.2)
# Requirement already satisfied: pyod>=0.9.5 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (1.0.7)
# Requirement already satisfied: requests>=2.22.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (2.28.1)
# Requirement already satisfied: pytorch-lightning>=1.5.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (1.9.0)
# Requirement already satisfied: xgboost>=1.6.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (1.7.1)
# Requirement already satisfied: torch>=1.8.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (1.10.2)
# Requirement already satisfied: joblib>=0.16.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (1.2.0)
# Requirement already satisfied: statsmodels>=0.13.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (0.13.5)
# Requirement already satisfied: scikit-learn>=1.0.1 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (1.2.0)
# Requirement already satisfied: catboost>=1.0.6 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (1.1.1)
# Requirement already satisfied: nfoursid>=1.0.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (1.0.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (3.5.1)
# Requirement already satisfied: numpy>=1.19.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (1.21.6)
# Requirement already satisfied: pandas>=1.0.5 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (1.5.3)
# Requirement already satisfied: holidays>=0.11.1 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (0.18)
# Requirement already satisfied: shap>=0.40.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (0.41.0)
# Requirement already satisfied: prophet>=1.1.1 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (1.1.1)
# Requirement already satisfied: tbats>=1.1.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (1.1.2)
# Requirement already satisfied: lightgbm>=3.2.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (3.3.4)
# Requirement already satisfied: xarray>=0.17.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from darts) (0.19.0)
# Requirement already satisfied: six in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from catboost>=1.0.6->darts) (1.10.0)
# Requirement already satisfied: graphviz in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from catboost>=1.0.6->darts) (0.20)
# Requirement already satisfied: plotly in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from catboost>=1.0.6->darts) (5.7.0)
# Requirement already satisfied: PyMeeus in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from holidays>=0.11.1->darts) (0.5.12)
# Requirement already satisfied: korean-lunar-calendar in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from holidays>=0.11.1->darts) (0.3.1)
# Requirement already satisfied: python-dateutil in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from holidays>=0.11.1->darts) (2.8.2)
# Requirement already satisfied: hijri-converter in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from holidays>=0.11.1->darts) (2.2.4)
# Requirement already satisfied: convertdate>=2.3.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from holidays>=0.11.1->darts) (2.4.0)
# Requirement already satisfied: wheel in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from lightgbm>=3.2.0->darts) (0.37.0)
# Requirement already satisfied: packaging>=20.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.3.0->darts) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.3.0->darts) (8.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.3.0->darts) (4.29.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.3.0->darts) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.3.0->darts) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.3.0->darts) (0.10.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from pandas>=1.0.5->darts) (2021.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from pmdarima>=1.8.0->darts) (0.29.24)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from pmdarima>=1.8.0->darts) (58.0.4)
# Requirement already satisfied: urllib3 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from pmdarima>=1.8.0->darts) (1.26.6)
# Requirement already satisfied: setuptools-git>=1.2 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from prophet>=1.1.1->darts) (1.2)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from prophet>=1.1.1->darts) (1.0.8)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from prophet>=1.1.1->darts) (0.0.9)
# Requirement already satisfied: ephem>=3.7.5.3 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from LunarCalendar>=0.0.9->prophet>=1.1.1->darts) (4.1.4)
# Requirement already satisfied: numba>=0.51 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from pyod>=0.9.5->darts) (0.55.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from numba>=0.51->pyod>=0.9.5->darts) (0.38.0)
# Requirement already satisfied: PyYAML>=5.4 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from pytorch-lightning>=1.5.0->darts) (5.4.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from pytorch-lightning>=1.5.0->darts) (0.11.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from pytorch-lightning>=1.5.0->darts) (2022.3.0)
# Requirement already satisfied: lightning-utilities>=0.4.2 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from pytorch-lightning>=1.5.0->darts) (0.5.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from pytorch-lightning>=1.5.0->darts) (4.4.0)
# Requirement already satisfied: aiohttp in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (3.8.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.22.0->darts) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.22.0->darts) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.22.0->darts) (3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=1.0.1->darts) (3.0.0)
# Requirement already satisfied: slicer==0.0.7 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from shap>=0.40.0->darts) (0.0.7)
# Requirement already satisfied: cloudpickle in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from shap>=0.40.0->darts) (1.6.0)
# Requirement already satisfied: patsy>=0.5.2 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from statsmodels>=0.13.0->darts) (0.5.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (21.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (1.8.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (6.0.2)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/changhyunlee/opt/anaconda3/lib/python3.8/site-packages (from plotly->catboost>=1.0.6->darts) (8.0.1)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from darts import TimeSeries
# from darts.models import NBEATSModel
from darts.dataprocessing.transformers import Scaler, MissingValuesFiller
from darts.metrics import mape, r2_score
from darts.datasets import EnergyDataset

# %%
def display_forecast(pred_series, ts_transformed, forecast_type, start_date=None):
    plt.figure(figsize=(8, 5))
    if start_date:
        ts_transformed = ts_transformed.drop_before(start_date)
    ts_transformed.univariate_component(0).plot(label="actual")
    pred_series.plot(label=("historic " + forecast_type + " forecasts"))
    plt.title(
        "R2: {}".format(r2_score(ts_transformed.univariate_component(0), pred_series))
    )
    plt.legend()

# %%
df = EnergyDataset().load().pd_dataframe()
df["generation hydro run-of-river and poundage"].plot()
plt.title("Hourly generation hydro run-of-river and poundage")
# Out:
# Text(0.5, 1.0, 'Hourly generation hydro run-of-river and poundage')

# %%
df_day_avg = df.groupby(df.index.astype(str).str.split(" ").str[0]).mean().reset_index()
filler = MissingValuesFiller()
scaler = Scaler()
series = scaler.fit_transform(
    filler.transform(
        TimeSeries.from_dataframe(
            df_day_avg, "time", ["generation hydro run-of-river and poundage"]
        )
    )
).astype(np.float32)
series.plot()
plt.title("Daily generation hydro run-of-river and poundage")
# Out:
# Text(0.5, 1.0, 'Daily generation hydro run-of-river and poundage')

# %%
train, val = series.split_after(pd.Timestamp("20170901"))

# %%
model_nbeats = NBEATSModel(
    input_chunk_length=30,
    output_chunk_length=7,
    generic_architecture=True,
    num_stacks=10,
    num_blocks=1,
    num_layers=4,
    layer_widths=512,
    n_epochs=100,
    nr_epochs_val_period=1,
    batch_size=800,
    model_name="nbeats_run",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/ryanjang123/kaggle_forecasting/model/NBeats_alpha.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ryanjang123/kaggle_forecasting/model/NBeats_alpha.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> model_nbeats = NBEATSModel(
#       <a href='vscode-notebook-cell:/Users/ryanjang123/kaggle_forecasting/model/NBeats_alpha.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a>     input_chunk_length=30,
#       <a href='vscode-notebook-cell:/Users/ryanjang123/kaggle_forecasting/model/NBeats_alpha.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a>     output_chunk_length=7,
#       <a href='vscode-notebook-cell:/Users/ryanjang123/kaggle_forecasting/model/NBeats_alpha.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a>     generic_architecture=True,
#       <a href='vscode-notebook-cell:/Users/ryanjang123/kaggle_forecasting/model/NBeats_alpha.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a>     num_stacks=10,
#       <a href='vscode-notebook-cell:/Users/ryanjang123/kaggle_forecasting/model/NBeats_alpha.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a>     num_blocks=1,
#       <a href='vscode-notebook-cell:/Users/ryanjang123/kaggle_forecasting/model/NBeats_alpha.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a>     num_layers=4,
#       <a href='vscode-notebook-cell:/Users/ryanjang123/kaggle_forecasting/model/NBeats_alpha.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a>     layer_widths=512,
#       <a href='vscode-notebook-cell:/Users/ryanjang123/kaggle_forecasting/model/NBeats_alpha.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a>     n_epochs=100,
#      <a href='vscode-notebook-cell:/Users/ryanjang123/kaggle_forecasting/model/NBeats_alpha.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a>     nr_epochs_val_period=1,
#      <a href='vscode-notebook-cell:/Users/ryanjang123/kaggle_forecasting/model/NBeats_alpha.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a>     batch_size=800,
#      <a href='vscode-notebook-cell:/Users/ryanjang123/kaggle_forecasting/model/NBeats_alpha.ipynb#X11sZmlsZQ%3D%3D?line=11'>12</a>     model_name="nbeats_run",
#      <a href='vscode-notebook-cell:/Users/ryanjang123/kaggle_forecasting/model/NBeats_alpha.ipynb#X11sZmlsZQ%3D%3D?line=12'>13</a> )
#
# NameError: name 'NBEATSModel' is not defined

# %%
model_nbeats.fit(train, val_series=val, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/ryanjang123/kaggle_forecasting/model/NBeats_alpha.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ryanjang123/kaggle_forecasting/model/NBeats_alpha.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> model_nbeats.fit(train, val_series=val, verbose=True)
#
# NameError: name 'model_nbeats' is not defined

# %%
pred_series = model_nbeats.historical_forecasts(
    series,
    start=pd.Timestamp("20170901"),
    forecast_horizon=7,
    stride=5,
    retrain=False,
    verbose=True,
)
display_forecast(pred_series, series, "7 day", start_date=pd.Timestamp("20170901"))

# %% [markdown]
# # Inpretable Version

# %%
model_nbeats = NBEATSModel(
    input_chunk_length=30,
    output_chunk_length=7,
    generic_architecture=False,
    num_blocks=3,
    num_layers=4,
    layer_widths=512,
    n_epochs=100,
    nr_epochs_val_period=1,
    batch_size=800,
    model_name="nbeats_interpretable_run",
)

# %%
model_nbeats.fit(series=train, val_series=val, verbose=True)

# %%
pred_series = model_nbeats.historical_forecasts(
    series,
    start=pd.Timestamp("20170901"),
    forecast_horizon=7,
    stride=5,
    retrain=False,
    verbose=True,
)
display_forecast(pred_series, series, "7 day", start_date=pd.Timestamp("20170901"))
