# %%
import numpy as np
import pandas as pd


train = pd.read_csv('../kaggle_data/train.csv')

# %%
train
# Out:
#                   row_id  cfips          county    state first_day_of_month  \
# 0        1001_2019-08-01   1001  Autauga County  Alabama         2019-08-01
# 1        1001_2019-09-01   1001  Autauga County  Alabama         2019-09-01
# 2        1001_2019-10-01   1001  Autauga County  Alabama         2019-10-01
# 3        1001_2019-11-01   1001  Autauga County  Alabama         2019-11-01
# 4        1001_2019-12-01   1001  Autauga County  Alabama         2019-12-01
# ...                  ...    ...             ...      ...                ...
# 122260  56045_2022-06-01  56045   Weston County  Wyoming         2022-06-01
# 122261  56045_2022-07-01  56045   Weston County  Wyoming         2022-07-01
# 122262  56045_2022-08-01  56045   Weston County  Wyoming         2022-08-01
# 122263  56045_2022-09-01  56045   Weston County  Wyoming         2022-09-01
# 122264  56045_2022-10-01  56045   Weston County  Wyoming         2022-10-01
#
#         microbusiness_density  active
# ...

# %%
cf = train['cfips'].values

# %%
cf
# Out:
# array([ 1001,  1001,  1001, ..., 56045, 56045, 56045], dtype=int64)

# %%
cfips = np.unique(cf) # 중복제거

# %%
cfips
# Out:
# array([ 1001,  1003,  1005, ..., 56041, 56043, 56045], dtype=int64)

# %%
fdom = train['first_day_of_month']

# %%
fdom
# Out:
# 0         2019-08-01
# 1         2019-09-01
# 2         2019-10-01
# 3         2019-11-01
# 4         2019-12-01
#              ...
# 122260    2022-06-01
# 122261    2022-07-01
# 122262    2022-08-01
# 122263    2022-09-01
# 122264    2022-10-01
# Name: first_day_of_month, Length: 122265, dtype: object

# %%
fdom1 = fdom.values

# %%
first_day_of_month = fdom1[0:39] # 매 county마다 39개월 간의 자료 사용

# %%
first_day_of_month
# Out:
# array(['2019-08-01', '2019-09-01', '2019-10-01', '2019-11-01',
#        '2019-12-01', '2020-01-01', '2020-02-01', '2020-03-01',
#        '2020-04-01', '2020-05-01', '2020-06-01', '2020-07-01',
#        '2020-08-01', '2020-09-01', '2020-10-01', '2020-11-01',
#        '2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01',
#        '2021-04-01', '2021-05-01', '2021-06-01', '2021-07-01',
#        '2021-08-01', '2021-09-01', '2021-10-01', '2021-11-01',
#        '2021-12-01', '2022-01-01', '2022-02-01', '2022-03-01',
#        '2022-04-01', '2022-05-01', '2022-06-01', '2022-07-01',
#        '2022-08-01', '2022-09-01', '2022-10-01'], dtype=object)

# %%
density = train['microbusiness_density'].values

# %%
density
# Out:
# array([3.0076818, 2.8848701, 3.0558431, ..., 1.7853955, 1.7853955,
#        1.7853955])

# %%
microbusiness_density = density.reshape(3135, 39)

# %%
df1 = pd.DataFrame(
    microbusiness_density,
    index=cfips,
    columns=first_day_of_month)

# %%
df = df1.T

# %%
df
# Out:
#                1001      1003      1005      1007      1009      1011   \
# 2019-08-01  3.007682  7.239156  1.073138  1.310777  1.544148  0.926372
# 2019-09-01  2.884870  7.290936  0.995794  1.305176  1.575892  0.998556
# 2019-10-01  3.055843  7.425439  1.160149  1.254761  1.546415  0.974495
# 2019-11-01  2.993233  7.426071  1.000628  1.254761  1.573625  1.022618
# 2019-12-01  2.993233  7.470274  1.000628  1.265965  1.555485  1.034649
# 2020-01-01  2.969090  7.413655  1.027229  1.253638  1.573217  1.060717
# 2020-02-01  2.909326  7.282522  1.022314  1.248041  1.536999  1.036333
# 2020-03-01  2.933231  7.309610  1.032144  1.264831  1.541526  1.060717
# 2020-04-01  3.000167  7.568799  1.086209  1.270428  1.577744  1.011948
# 2020-05-01  3.004948  7.603275  1.081294  1.287217  1.575481  0.890027
# 2020-06-01  3.019292  7.708551  0.997739  1.304007  1.570953  0.926603
# 2020-07-01  3.083837  7.783045  0.987909  1.343183  1.602644  0.914411
# ...
